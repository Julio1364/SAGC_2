# %%
from tkinter import *
from csv import *
import os.path
import tkinter as tk
from tkinter import ttk
from datetime import datetime
from os import remove
from tkinter.font import Font
import pdfkit
import jinja2
from tkinter.filedialog import askopenfilename
import time

######VENTANA#######
ventana=Tk()

ventana.resizable(0,0)

ventana.title("ICAyCC-Constancias")
ventana.iconbitmap("Imagenes/ico.ico")
ventana.geometry("1200x600")

##Funcionces
DatAl=0
def Mas1():
    global DatAl
    global longitud
    DatAl+=1
    if DatAl>longitud:
        DatAl=0
    datprev()
def Menos1():
    global DatAl
    global longitud
    if DatAl>0:
        DatAl-=1
    if DatAl<0:
        DatAl=longitud
    datprev()
    
def datprev():
    global EdataAl
    global EcorAl
    global longitud
    global DatAl
    num4 = varOpcion7.get()
    num= varOpcion.get()
    num2= varOpcion6.get()
    btn_font = Font(size=19)
    btn_font2 = Font(size=7)
    if num4==2:
        Pref=pre2
    ND=EdataAl[DatAl][0]
    NX=EcorAl[DatAl][1][0]
    NY=EcorAl[DatAl][1][1]
    PD=EdataAl[DatAl][1]
    PX=EcorAl[DatAl][2][0]
    PY=EcorAl[DatAl][2][1]
    P1D=EdataAl[DatAl][2]
    P1X=EcorAl[DatAl][3][0]
    P1Y=EcorAl[DatAl][3][1]
    P2D=EdataAl[DatAl][3]
    P2X=EcorAl[DatAl][4][0]
    P2Y=EcorAl[DatAl][4][1]
    Fecha=EdataAl[DatAl][4]
    ##Firmas 
    F1ND=EdataAl[DatAl][5]
    F1NX=EcorAl[DatAl][6][0]
    F1NY=EcorAl[DatAl][6][1]
    F1CD=EdataAl[DatAl][6]
    F1CX=EcorAl[DatAl][7][0]
    F1CY=EcorAl[DatAl][7][1]
    F2ND=EdataAl[DatAl][7]
    F2NX=EcorAl[DatAl][8][0]
    F2NY=EcorAl[DatAl][8][1]
    F2CD=EdataAl[DatAl][8]
    F2CX=EcorAl[DatAl][9][0]
    F2CY=EcorAl[DatAl][9][1]
    ##FOLIO
    FolD=EdataAl[DatAl][13]
    FolX=EcorAl[DatAl][14][0]
    FolY=EcorAl[DatAl][14][1]
    DatAlP= DatAl+1
    Label(ventana, text=(DatAlP ,"/" ,longitud), font=btn_font2).place(x=690,y=120)
    if num==1:
        Label(Pref, text="RECONOCIMIENTO", font=btn_font).place(x=148.20,y=80)
    if num==2:
        Label(Pref, text="CONSTANCIA", font=btn_font).place(x=190.93,y=80)
    Label(Pref, text=ND, font=btn_font).place(x=NX, y=NY)
    Label(Pref, text=PD, font=btn_font2).place(x=PX,y=PY)
    Label(Pref, text=P1D, font=btn_font2).place(x=P1X,y=P1Y)
    if num2==1:
        Label(Pref, text=P2D, font=btn_font2).place(x=P2X,y=P2Y) 
    Label(Pref, text="Ciudad Universitaria, Cd. Mx a "+ Fecha, font=btn_font2).place(x=190.93,y=230)
    ##Firmas
    if num4==2:
        Label(Pref, text=F1ND, font=btn_font2).place(x=F1NX,y=F1NY)
        Label(Pref, text=F1CD, font=btn_font2).place(x=F1CX,y=F1CY)
        Label(Pref, text=F2ND, font=btn_font2).place(x=F2NX,y=F2NY)
        Label(Pref, text=F2CD, font=btn_font2).place(x=F2CX,y=F2CY)
    ##Folio
    Label(Pref, text=FolD, font=btn_font2).place(x=FolX,y=FolY)
    
def prev():
    global PA
    global ruta
    global longitud
    global EdataAl
    global EcorAl
    num4 = varOpcion7.get()
    num2= varOpcion6.get()
    num3= varOpcion5.get()
    num= varOpcion.get()

    if not ruta=="" and not num4==0 and not num==0: 
        if PA==2:
            ###Logica###
            if num==1:
                V1="RECONOCIMIENTO"
                V16="Otorga el presente"
                Cor1=-850
            if num==2:
                V1="CONSTANCIA"
                V16="Se otorga la presente"
                Cor1=-700
            longitud=0
            act=open(ruta,"r")
            ño=act.readline()
            for n in range(0,1000):
                if not ño=="":
                     longitud+=1
                     ño=act.readline()
            act.close()
            act=open(ruta,"r")
            act.readline()
            longitud-=1
            EdataAl=[]
            EcorAl=[]
            
            for i in range (0,longitud):
                EdataAl.append([])
                for c in range(14):
                    EdataAl[i].append(c)
                    
            for i in range (0,longitud):
                EcorAl.append([])
                for c in range(0,15):
                    EcorAl[i].append([])
                    for ñ in range(0,2):
                        EcorAl[i][c].append(ñ)
                        
            for x in range(0, longitud):
                
                at= act.readline()
                l=len(at)
                dato=1
                V2=""
                V3=""
                V4=""
                V5=""
                V6=""
                V7=""
                V8=""
                V9=""
                V10=""
                V11=""
                V12=""
                V13=""
                V14=""
                V15=""
                if num==1:
                    EcorAl[x][0][0]=248.20
                if num==2:
                    EcorAl[x][0][0]=290.93
                EcorAl[x][1][0]=108.29
                EcorAl[x][1][1]=130
                EcorAl[x][2][0]=105.44
                EcorAl[x][2][1]=172
                EcorAl[x][3][0]=62.69
                EcorAl[x][3][1]=185.82
                EcorAl[x][4][0]=62.69
                EcorAl[x][4][1]=205.51
                EcorAl[x][5][0]=194
                EcorAl[x][5][1]=320.96
                if num4==1:
                    EcorAl[x][6][0]=119.69
                    EcorAl[x][6][1]=278.45
                    EcorAl[x][7][0]=91.19
                    EcorAl[x][7][1]=290
                if num4==2:
                    EcorAl[x][6][0]=25.69
                    EcorAl[x][6][1]=278.45
                    EcorAl[x][7][0]=11.19
                    EcorAl[x][7][1]=290
                    EcorAl[x][8][0]=364.77
                    EcorAl[x][8][1]=278.45
                    EcorAl[x][9][0]=350.5
                    EcorAl[x][9][1]=290
                if num4==3:
                    EcorAl[x][6][0]=125.69
                    EcorAl[x][6][1]=358.45
                    EcorAl[x][7][0]=111.19
                    EcorAl[x][7][1]=370.55
                    EcorAl[x][8][0]=464.77
                    EcorAl[x][8][1]=358.45
                    EcorAl[x][9][0]=450.5
                    EcorAl[x][9][1]=370.55
                    EcorAl[x][10][0]=285.29
                    EcorAl[x][10][1]=358.45
                    EcorAl[x][11][0]=270
                    EcorAl[x][11][1]=370.55
                if num4==4:
                    EcorAl[x][6][0]=111.69
                    EcorAl[x][6][1]=358.45
                    EcorAl[x][7][0]=105.19
                    EcorAl[x][7][1]=370.55
                    EcorAl[x][8][0]=214.77
                    EcorAl[x][8][1]=358.45
                    EcorAl[x][9][0]=209.5
                    EcorAl[x][9][1]=370.55
                    EcorAl[x][10][0]=347.29
                    EcorAl[x][10][1]=358.45
                    EcorAl[x][11][0]=339
                    EcorAl[x][11][1]=370.55
                    EcorAl[x][12][0]=465.29
                    EcorAl[x][12][1]=358.45
                    EcorAl[x][13][0]=450
                    EcorAl[x][13][1]=370.55
                EcorAl[x][14][0]=235
                EcorAl[x][14][1]=290
                   
                
                for n in range(0,l):
                    if at[n]==',':
                        dato+=1
                    if not at[n]==',':
                        if dato==1:
                            V2+=at[n]
                        if dato==2:
                            V3+=at[n]
                        if dato==3:
                            V4+=at[n]
                        if dato==4:
                            if num2==1:
                                V5+=at[n]
                            if num2==0:
                                V6+=at[n]
                        if dato==5:
                            if num2==0:
                                V7+=at[n]
                            if num2==1:
                                V6+=at[n]
                        if dato==6:
                            if num2==0:
                                V8+=at[n]
                            if num2==1:
                                V7+=at[n]
                        if dato==7:
                            if num2==0:
                                if num4==1 and num3==1:
                                    V15+=at[n]
                                if num4==2 or num4==3 or num4==4:
                                    V9+=at[n]
                            if num2==1:
                                V8+=at[n]
                        if dato==8:
                            if num2==0:
                                if num4==2 or num4==3 or num4==4:
                                    V10+=at[n]
                            if num2==1:
                                if num4==1 and num3==1:
                                    V15+=at[n]
                                if num4==2 or num4==3 or num4==4:
                                    V9+=at[n]
                        if dato==9:
                            if num2==0:
                                if num4==2 and num3==1:
                                    V15+=at[n]
                                if num4==3 or num4==4:
                                    V11+=at[n]
                            if num2==1:
                                if num4==2 or num4==3 or num4==4:
                                    V10+=at[n]
                        if dato==10:
                            if num2==0:
                                if num4==3 or num4==4:
                                    V12+=at[n]
                            if num2==1:
                                if num4==2 and num3==1:
                                    V15+=at[n]
                                if num4==3 or num4==4:
                                    V11+=at[n]
                        if dato==11:
                            if num2==0:
                                if num4==3 and num3==1:
                                    V15+=at[n]
                                if num4==4:
                                    V13+=at[n]
                            if num2==1:
                                if num4==3 or num4==4:
                                    V12+=at[n]
                        if dato==12:
                            if num2==0:
                                if num4==4:
                                    V14+=at[n]
                            if num2==1:
                                if num4==3 and num3==1:
                                    V15+=at[n]
                                if num4==4:
                                    V13+=at[n]
                        if dato==13:
                            if num2==0:
                                if num4==4 and num3==1:
                                    V15+=at[n]
                            if num2==1:
                                if num4==4:
                                    V14+=at[n]
                        if dato==14:
                            if num2==1:
                                if num4==4 and num3==1:
                                    V15+=at[n] 
                EdataAl[x][0]=V2
                EdataAl[x][1]=V3
                EdataAl[x][2]=V4
                EdataAl[x][3]=V5
                EdataAl[x][4]=V6
                EdataAl[x][5]=V7
                EdataAl[x][6]=V8
                EdataAl[x][7]=V9
                EdataAl[x][8]=V10
                EdataAl[x][9]=V11
                EdataAl[x][10]=V12
                EdataAl[x][11]=V13
                EdataAl[x][12]=V14
                EdataAl[x][13]=V15

            # print(EcorAl)
            ###Grafica###
        
            olvidar(TV)
            olvidar(a)
            olvidar(b)
            olvidar(eventosb1)
            olvidar(eventosb2)
            olvidar(FiD)
            olvidar(aD)
            olvidar(bD)
            olvidar(cD)
            olvidar(dD)
            olvidar(Pon_2)
            olvidar(FOL2)
            olvidar(EA)
            olvidar(pre1)
            olvidar(RutaLa)
            EA1.place(x=720,y=120)
            EA1_2.place(x=750,y=120)
            Gene1.place(x=720, y=200)
            Gene1_2.place(x=720, y=320)
            Save1.place(x=250, y=400)
            Save1_2.place(x=400, y=400)
    
            if num4==1:
                recordar(pre)
                olvidar(pre4)
                olvidar(pre3)
                olvidar(pre2)
                pre.place(x=100,y=80)
            if num4==2:
                recordar(pre2)
                olvidar(pre4)
                olvidar(pre3)
                olvidar(pre)
                pre2.place(x=100,y=80)
            if num4==3:
                recordar(pre3)
                olvidar(pre4)
                olvidar(pre)
                olvidar(pre2)
                pre3.place(x=100,y=80)
            if num4==4:
                recordar(pre4)
                olvidar(pre)
                olvidar(pre3)
                olvidar(pre2)
                pre4.place(x=100,y=80)
            datprev()
    else:
        advertencia("Conteste todo")
        
    if PA==1:
        olvidar(FiD)
        olvidar(aD)
        olvidar(bD)
        olvidar(cD)
        olvidar(dD)
        olvidar(Pon_2)
        olvidar(EA)
        olvidar(pre1)
        olvidar(TV2)
        olvidar(a2)
        olvidar(b2)
        olvidar(Mo)
        olvidar(MO)
        olvidar(Cuan1)
        olvidar(Cuan2)
        EA1.place(x=430,y=120)
        EA1_2.place(x=460,y=120)
        Gene1.place(x=430, y=200)
        Gene1_2.place(x=430, y=320)
        Save1.place(x=1070, y=200)
        Save1_2.place(x=1070, y=320)
        
def otorga():
     global varOpcionc
     global varOpcionModo
     global varOpcionModO
    
     num=varOpcionc.get()
     num2=varOpcionModo.get()
     num3=varOpcionModO.get()
     if num==1:
        olvidar(Mo)
        olvidar(MO)
        num2=0
        num3=0
     if num==2:
        Mo.place(x=860, y=330)
        MO.place(x=860, y=380)
     if num2==0:
        olvidar(Cuan1)
     if num3==0:
        olvidar(Cuan2)
     if num2==1:
        Cuan1.place(x=860,y=350)
     if num3==1:
        Cuan2.place(x=860,y=410)
         
def advertencia(mensaje):
    ventana_secundaria = tk.Toplevel()
    ventana_secundaria.title("Advertencia")
    ventana_secundaria.config(width=250, height=100)
    ventana_secundaria.iconbitmap("Imagenes/ico.ico")
    ventana_secundaria.resizable(0,0)
    adv=Frame(ventana_secundaria, width=200, height=100)
    adv.pack()
    adv.place(x=50,y=25)
    Label(adv, text=mensaje).place(x=0, y=0)
    ventana_secundaria.focus()
    ventana_secundaria.grab_set() 
    boton_cerrar = Button(ventana_secundaria,text="Cerrar ventana",command=ventana_secundaria.destroy)
    boton_cerrar.place(x=87, y=65)
def olvidar(a):
    a.pack()
    a.pack_forget()    
def recordar(a):
    a.pack()
def advertencia(mensaje):
    ventana_secundaria = tk.Toplevel()
    ventana_secundaria.title("Advertencia")
    ventana_secundaria.config(width=250, height=100)
    ventana_secundaria.iconbitmap("Imagenes/ico.ico")
    ventana_secundaria.resizable(0,0)
    adv=Frame(ventana_secundaria, width=200, height=100)
    adv.pack()
    adv.place(x=50,y=25)
    Label(adv, text=mensaje).place(x=0, y=0)
    ventana_secundaria.focus()
    ventana_secundaria.grab_set() 
    boton_cerrar = Button(ventana_secundaria,text="Cerrar ventana",command=ventana_secundaria.destroy)
    boton_cerrar.place(x=87, y=65)
def archivoruta():
    global ruta
    global rutajue
    ruta = askopenfilename()
    rutajue= (ruta[-20:])
    Label(RutaLa, text="Usted eligio:"+rutajue).place(x=0, y=0)
    if ruta=="":
     rutajue= "      Sin ruta                           "
     Label(RutaLa, text="Usted eligio:"+rutajue).place(x=0, y=0)
def regresar():
    global PA
    global x2
    global x3
    global cir1
    global cir2
    if PA==1:
        mov1tr()
        menu()
    if PA==2:
        mov2tr()
        menu()
    
##Menu
def menu():
    fondo.place(x=x1, y=125)
    cir1.place(x=x2, y=125)
    cir2.place(x=x3, y=404)
    cursosb.place(x=800, y=250)
    eventosb.place(x=180, y=250)
    Ins.place(x=0, y=0)
    Unam.place(x=1080, y=0)
##Pagina Archivos
def Earch1():
     olvidar(eventosb1)
     olvidar(eventosb2)
     olvidar(cir1)
     olvidar(cir2)
     FiD.place(x=180,y=230)
     aD.place(x=240,y=230)
     bD.place(x=270,y=230)
     cD.place(x=300,y=230)
     dD.place(x=330,y=230)
     Pon_2.place(x=180, y=280)
     FOL2.place(x=180,y=340)
     EA.place(x=260, y=100)
     RutaLa.place(x=520, y=150)
     pre1.place(x=480, y=300)
     TV.place(x=180,y=200)
     a.place(x=240,y=200)
     b.place(x=350,y=200)
def Carch1():
     olvidar(cursosb1)
     olvidar(cursosb2)
     olvidar(cir1)
     olvidar(cir2)
     otorga()
     FiD.place(x=860,y=230)
     aD.place(x=920,y=230)
     bD.place(x=950,y=230)
     cD.place(x=970,y=230)
     dD.place(x=1000,y=230)
     Pon_2.place(x=860, y=280)
     EA.place(x=860, y=100)
     pre1.place(x=480, y=300)
     TV2.place(x=860,y=200)
     a2.place(x=920,y=200)
     b2.place(x=1030,y=200)

x1=430
x2=575
x3=477
def mov1():
    global x1
    global x2
    global x3
    global cir1
    global cir2
    global fondo
    x1-=10
    x2+=7
    x3+=2
    cir1.place(x=x2, y=125)
    cir2.place(x=x3, y=404)
    fondo.place(x=x1, y=125)
    ventana.update()
def mov1t():
    global x1
    global PA
    olvidar(cursosb)
    olvidar(eventosb)
    while x1>80:
        mov1()
        time.sleep(.0001)
    if x1<=80:
        regresar.place(x=950, y=480)
        cursosb1.place(x=790, y=200)
        cursosb2.place(x=520, y=315)
        PA=1
def mov1r():
    global x1
    global x2
    global x3
    global cir1
    global cir2
    global fondo
    x1+=10
    x2-=7
    x3-=2
    cir1.place(x=x2, y=125)
    cir2.place(x=x3, y=404)
    fondo.place(x=x1, y=125)
    ventana.update()
def mov1tr():
    global x1
    global PA
    olvidar(regresar)
    olvidar(cursosb1)
    olvidar(cursosb2)
    olvidar(FiD)
    olvidar(aD)
    olvidar(bD)
    olvidar(cD)
    olvidar(dD)
    olvidar(Pon_2)
    olvidar(EA)
    olvidar(pre1)
    olvidar(TV2)
    olvidar(a2)
    olvidar(b2)
    olvidar(Mo)
    olvidar(MO)
    olvidar(Cuan1)
    olvidar(Cuan2)
    olvidar(EA1)
    olvidar(EA1_2)
    olvidar(Save1)
    olvidar(Save1_2)
    olvidar(Gene1)
    olvidar(Gene1_2)
    while not x1==430:
        mov1r()
        time.sleep(.0001)
    if x1==430:
        PA=0
def mov2():
    global x1
    global x2
    global x3
    global cir1
    global cir2
    global fondo
    x1+=10
    x2-=2
    x3-=7
    cir1.place(x=x2, y=125)
    cir2.place(x=x3, y=404)
    fondo.place(x=x1, y=125)
    ventana.update()
def mov2t():
    global x1
    global PA
    olvidar(cursosb)
    olvidar(eventosb)
    while x1<=820:
        mov2()
        time.sleep(.0001)
    if x1>=820:
        eventosb1.place(x=170, y=315)
        eventosb2.place(x=470, y=200)
        regresar.place(x=15, y=480)
        PA=2
def mov2r():
    global x1
    global x2
    global x3
    global cir1
    global cir2
    global fondo
    x1-=10
    x2+=2
    x3+=7
    cir1.place(x=x2, y=125)
    cir2.place(x=x3, y=404)
    fondo.place(x=x1, y=125)
    ventana.update()
def mov2tr():
    global x1
    global PA
    olvidar(TV)
    olvidar(a)
    olvidar(b)
    olvidar(regresar)
    olvidar(eventosb1)
    olvidar(eventosb2)
    olvidar(FiD)
    olvidar(aD)
    olvidar(bD)
    olvidar(cD)
    olvidar(dD)
    olvidar(Pon_2)
    olvidar(FOL2)
    olvidar(EA)
    olvidar(pre1)
    olvidar(EA1)
    olvidar(EA1_2)
    olvidar(Save1)
    olvidar(Save1_2)
    olvidar(Gene1)
    olvidar(Gene1_2)
    olvidar(pre4)
    olvidar(pre)
    olvidar(pre3)
    olvidar(pre2)
    olvidar(RutaLa)
    while not x1==430:
        mov2r()
        time.sleep(.0001)
        if x1==430:
            PA=0
###MENUU

##Titulo
btn_font = Font(size=15)
Label(ventana, text="“Sistema automatizado de generación de constancias del ICAyCC”", font=btn_font).place(x=350,y=50)

###fondo###
fondo=Frame(ventana, width=693, height=695)
fondoi = PhotoImage(file = "Imagenes/logo1.png")
Label(fondo, image=fondoi).place(x=0, y=0)

##Ins
Ins=Frame(ventana, width=272, height=76)
Insi = PhotoImage(file = "Imagenes/logoi.png")
Label(Ins, image=Insi).place(x=0, y=0)

##Unam
Unam=Frame(ventana, width=101, height=113)
Unami = PhotoImage(file = "Imagenes/unam.png")
Label(Unam, image=Unami).place(x=0, y=0)


##Cir1##
cir1=Frame(ventana, width=168, height=70)
cir1i = PhotoImage(file = "Imagenes/cir1.png")
Label(cir1, image=cir1i).place(x=0, y=0)

##Cir2##
cir2=Frame(ventana, width=168, height=70)
cir2i = PhotoImage(file = "Imagenes/cir1.png")
Label(cir2, image=cir2i).place(x=0, y=0)

##cursos boton
cursosb=Button(ventana, text="Cursos", width=30, height=5, command=mov1t)

##eventos boton
eventosb=Button(ventana, text="Eventos", width=30, height=5, command=mov2t)

PA=0

##Boton regresar:
regresar=Button(ventana, text="Regresar", width=30, height=5, command=regresar)


##PAGINA EVENTOS:
#1
eventosb1=Button(ventana, text="Archivo", width=30, height=5, command=Earch1)
eventosb2=Button(ventana, text="Individual", width=30, height=5, command=mov2t)
##2
#Archivo 1
##Boton Elegir Archivo
ruta="    Sin ruta"
EA=Button(ventana, text="Elija Archivo" , width=30, height=5,command=archivoruta)
RutaLa=Frame(ventana, width=180, height=20)
Label(RutaLa, text="Usted eligio:"+ruta).place(x=0, y=0)
##Boton Previsualizar
pre1=Button(ventana, text="Previsualizar", width=30, height=5, command=prev)
pre1.config(bg="green")
##Boton Folio 2
FOL2=Frame(ventana, width=120, height=20)
varOpcion5=IntVar()
Checkbutton(FOL2, text="Se requiere FOLIO",variable=varOpcion5, onvalue=1, offvalue=0).place(x=0, y=0)
##Boton Parrafo 2
varOpcion6=IntVar()
Pon_2=Frame(ventana, width=113, height=20)
Checkbutton(Pon_2, text="Segundo Parrafo",variable=varOpcion6, onvalue=1, offvalue=0).place(x=0, y=0)
##Firmas D
FiD=Frame(ventana, width=100, height=20)
Label(FiD, text="Firmas:").place(x=0, y=0)
varOpcion7=IntVar()
aD=Frame(ventana, width=40, height=20)
Radiobutton(aD, text="1", variable=varOpcion7, value=1).place(x=0, y=0)
bD=Frame(ventana, width=40, height=20)
Radiobutton(bD, text="2", variable=varOpcion7, value=2).place(x=0, y=0)
cD=Frame(ventana, width=40, height=20)
Radiobutton(cD, text="3", variable=varOpcion7, value=3).place(x=0, y=0)
dD=Frame(ventana, width=40, height=20)
Radiobutton(dD, text="4", variable=varOpcion7, value=4).place(x=0, y=0)
varOpcion=IntVar()
TV=Frame(ventana, width=100, height=20)
Label(TV, text="Se otorga:").place(x=0, y=0)
a=Frame(ventana, width=120, height=20)
Radiobutton(a, text="Reconocimiento", variable=varOpcion, value=1).place(x=0, y=0)
b=Frame(ventana, width=150, height=20)
Radiobutton(b, text="Constancia", variable=varOpcion, value=2).place(x=0, y=0)

##3
EA1=Button(ventana, text="<--", command=Menos1)
EA1_2=Button(ventana, text="-->", command=Mas1)
Save1=Button(ventana, text="Guardar", width=15, height=2)
Save1_2=Button(ventana, text="Guardar \npara todos", width=15, height=2)
Gene1=Button(ventana, text="Generar actual", width=15, height=2)
Gene1_2=Button(ventana, text="Generar \npara todos", width=15, height=2)
Gene1.config(bg="green")
Gene1_2.config(bg="green")

pre=Frame(ventana, width=550, height=310)
prei = PhotoImage(file = "Imagenes/1.png")
Label(pre, image=prei).place(x=0, y=0)

pre2=Frame(ventana, width=550, height=310)
prei2 = PhotoImage(file = "Imagenes/2.png")
Label(pre2, image=prei2).place(x=0, y=0)

pre3=Frame(ventana, width=550, height=310)
prei3 = PhotoImage(file = "Imagenes/3.png")
Label(pre3, image=prei3).place(x=0, y=0)

pre4=Frame(ventana, width=550, height=310)
prei4 = PhotoImage(file = "Imagenes/4.png")
Label(pre4, image=prei4).place(x=0, y=0)

##PAGINA CURSOS:
#1
cursosb1=Button(ventana, text="Individual", width=30, height=5, command=mov2t)
cursosb2=Button(ventana, text="Archivo", width=30, height=5, command=Carch1)
#2
varOpcionc=IntVar()
TV2=Frame(ventana, width=100, height=20)
Label(TV2, text="Se otorga:").place(x=0, y=0)
a2=Frame(ventana, width=120, height=20)
Radiobutton(a2, text="Reconocimiento", variable=varOpcionc, value=1, command=otorga).place(x=0, y=0)
b2=Frame(ventana, width=150, height=20)
Radiobutton(b2, text="Diploma", variable=varOpcionc, value=2, command=otorga).place(x=0, y=0)
##Modulos
varOpcionModo=IntVar()
varOpcionModO=IntVar()
Mo=Frame(ventana, width=150, height=20)
Checkbutton(Mo, text="Modulos Obligatorios", variable=varOpcionModo, onvalue=1, offvalue=0, command=otorga).place(x=0, y=0)
MO=Frame(ventana, width=150, height=20)
Checkbutton(MO, text="Modulos Optativos", variable=varOpcionModO, onvalue=1, offvalue=0, command=otorga).place(x=0, y=0)
Cuan1=Frame(ventana, width=320, height=30)
Label(Cuan1, text="Cuantos modulos?:").place(x=0, y=0)
Cuan1entry=Entry(Cuan1)
Cuan1entry.place(x=150,y=0)
Cuan2=Frame(ventana, width=320, height=30)
Label(Cuan2, text="Cuantos modulos?:").place(x=0, y=0)
Cuan2entry=Entry(Cuan2)
Cuan2entry.place(x=150,y=0)

CA1=Button(ventana, text="<--")
CA1_2=Button(ventana, text="-->")

##Coordenadas de Eventos
longitud=0
##Nombre
Cor2=-990
##Participacion
Cor3X=-1000
Cor3Y=-70
##Ponencia 1
Cor4X=-1150
Cor4Y=-140
##Ponencia 2
Cor5X=-1150
Cor5Y=-180
#####FIRMAS 
###Primera Paginas
PFN1=-950
PFC1=-1050
##Segunda Pagina
PFN2=-1580
PFC2=-1630
SFN2=-390
SFC2=-440
##Tercera Pagina 
TFN3=-1020
TFC3=-1000
SFN3=-470
SFC3=-420
##Cuarta Pagina 
PFN4=-1685
PFC4=-1650
SFN4=-1270
SFC4=-1285
TFN4=-800
TFC4=-830
CFN4=-390
CFC4=-440

# #Main principal
# main_frame = Frame(ventana, width=240, height=800)
# #Canvas
# canvas = Canvas(main_frame)
# #Scroll bar al canvas
# sb = ttk.Scrollbar(main_frame, orient=VERTICAL, command=canvas.yview)
# #configurar el camvas
# canvas.configure(yscrollcommand=sb.set)
# canvas.bind('<Configure>', lambda e: canvas.configure(scrollregion = canvas.bbox("all")))
# #crear un frame en canvas 
# sframe = Frame(canvas, width=900, height=13400)
# #añadir el nuevo frame 
# canvas.create_window((0,0), window=sframe, anchor="nw")

menu()

ventana.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Program Files\Python311\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\paty0\AppData\Local\Temp\ipykernel_4928\2321768655.py", line 31, in Mas1
#     datprev()
#   File "C:\Users\paty0\AppData\Local\Temp\ipykernel_4928\2321768655.py", line 53, in datprev
#     ND=EdataAl[DatAl][0]
#        ~~~~~~~^^^^^^^
# IndexError: list index out of range
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Program Files\Python311\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\paty0\AppData\Local\Temp\ipykernel_4928\2321768655.py", line 31, in Mas1
#     datprev()
#   File "C:\Users\paty0\AppData\Local\Temp\ipykernel_4928\2321768655.py", line 53, in datprev
#     ND=EdataAl[DatAl][0]
#        ~~~~~~~^^^^^^^
# ...
